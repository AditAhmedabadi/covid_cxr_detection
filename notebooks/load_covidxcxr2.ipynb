# %%
from google.colab import drive, files
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/covid_detection'
# Out:
# Mounted at /content/gdrive

# %%
files.upload()
# Out:
#      <input type="file" id="files-93c4a366-8418-43c9-b52f-1a5c1191038b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93c4a366-8418-43c9-b52f-1a5c1191038b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (4).json
# {'kaggle.json': b'{"username":"ureshiadit","key":"903230ad8325d37a7b08294c73c4d126"}'}

# %%
# !pip install kaggle
# !pip install --upgrade --force-reinstall --no-deps kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# ...
#   Using cached kaggle-1.5.12-py3-none-any.whl
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# ...
# kaggle.json

# %%
# !kaggle datasets list -s covidx-cxr2
# Out:
# ref                    title         size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------  ------------  ----  -------------------  -------------  ---------  ---------------
# andyczhao/covidx-cxr2  COVIDx CXR-2  13GB  2021-11-23 03:45:04           2708        101  0.875

# %%
# !kaggle datasets download -d andyczhao/covidx-cxr2 -p /content/gdrive/My\ Drive/covid_xray_detection/dataset
# Out:
# covidx-cxr2.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import os
os.chdir('/content/gdrive/MyDrive/covid_xray_detection/dataset')

# %%
import zipfile
with zipfile.ZipFile('/content/gdrive/MyDrive/covid_xray_detection/dataset/covidx-cxr2.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/gdrive/MyDrive/covid_xray_detection/dataset')
